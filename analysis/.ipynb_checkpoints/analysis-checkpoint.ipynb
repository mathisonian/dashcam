# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from altair import Chart, load_dataset

# %%
csv_path = "../data/consumer-complaints.csv"

# %%
complaints = pd.read_csv(csv_path, parse_dates=[0], infer_datetime_format=True)
# Out:
# //anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (5,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
complaints['Date received'].describe()
# Out:
# count                  730212
# unique                   1920
# top       2017-01-19 00:00:00
# freq                     2036
# first     2011-12-01 00:00:00
# last      2017-03-03 00:00:00
# Name: Date received, dtype: object

# %%
complaints.head()
# Out:
#   Date received                  Product                  Sub-product  \
# 0    2013-07-29            Consumer Loan                 Vehicle loan
# 1    2013-07-29  Bank account or service             Checking account
# 2    2013-07-29  Bank account or service             Checking account
# 3    2013-07-29  Bank account or service             Checking account
# 4    2013-07-29                 Mortgage  Conventional fixed mortgage
#
#                                       Issue Sub-issue  \
# 0                Managing the loan or lease       NaN
# 1                 Using a debit or ATM card       NaN
# 2   Account opening, closing, or management       NaN
# 3                  Deposits and withdrawals       NaN
# 4  Loan servicing, payments, escrow account       NaN
#
#   Consumer complaint narrative Company public response  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# ...

# %%
company = complaints.groupby(['Company'])

# %%
company.head()
# Out:
#        Date received                  Product  \
# 0         2013-07-29            Consumer Loan
# 1         2013-07-29  Bank account or service
# 2         2013-07-29  Bank account or service
# 3         2013-07-29  Bank account or service
# 4         2013-07-29                 Mortgage
# 5         2013-07-29  Bank account or service
# 6         2013-07-29          Debt collection
# 7         2013-07-29          Debt collection
# 8         2013-07-29              Credit card
# 9         2013-07-29                 Mortgage
# 10        2013-07-29                 Mortgage
# 11        2013-07-29                 Mortgage
# 12        2013-07-29                 Mortgage
# 13        2013-07-29          Debt collection
# 14        2013-07-29          Debt collection
# 15        2013-07-29                 Mortgage
# 16        2013-07-29                 Mortgage
# 17        2013-07-29                 Mortgage
# 18        2013-07-29                 Mortgage
# ...

# %%
filter(lambda x: 'XXXX' not in x, complaints[complaints['Consumer complaint narrative'].notnull()]['Consumer complaint narrative'])
# Out:
# ['Capitol One 360 keeps changing what I owe on my loan and they also changed my mailing address on there website. They changed it to a P.O. box I know longer use and I never even told them I had it. It shows on my credit report that I have on and thats it. Im still at the same address as the one from when I purchased the vehicle so its a little scary that my address just changes like that. The credit bureaus are reporting a different amount than I owe and Im getting notices that my car loan increased.',
#  "I was a victim of identity theft and noticed a collection from CREDIT CONTROL SERVI I 've attempted to dispute multiple times however no response on their end. Not sure what else to do. Police department told me to contact the federal trade commision which I wrote a formal complaint against CREDIT CONTROL SERVI in regards to this matter. The FTC also instructed me to complete a id theft affidavit through identity theft.gov. Attached is my document. Thank you",
# ...

# %%
nan
